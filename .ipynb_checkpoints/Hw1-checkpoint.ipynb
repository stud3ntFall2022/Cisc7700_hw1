# %% [markdown]
# ## Table of Contents
#
# * [Homework# 1](#Homework#1)
#     * [Initialisation Package Import/Install](#Import_Packages)
#     * [Load Data into DataFrame](#Data_Load)
#     * [DataFrame Statisitics](#DataFrame_Statistics)
#     * [DataFrame Formating](#DataFrame_Formating)
#     * [KNeighbors Classifier](#KNeighborsClassifier)
#     * [Dataset Predictions](#Predictions)
# * [Homework# 2](#Homework#2)
#     * [Histogram Plots](#Histograms)
#     * [Mean and STD](#Mean_STD)
#     * [Median and IQR](#Median_IQR)
#     * [Bootstrap method](#Bootstrap_Method)
# * [Homework# 3](#Homework#3)
#     * [Load model data](#Data_model_load)
#     * [Calculate data model](#Calculate_data_model)
#     * [Calculate model TP TN FP FN](#Calculate_TP_TN_FP_FN)
#     * [Calculate model accuracy](#Model_Accuracy)
#     * [Calculate model precision](#Model_Precission)
#     * [Confusion Matrix](#Confusion_Matrix)
# * [Homework# 4](#Homework#4)
#     * [Linear model](#Linear_Model)
#         *[Revenues](#Revenue)
#         *[Earnings](#Earning)
#         *[Dividends](#Dividend)
#     * [Logarithmic model](#Logarithmic_Model)
#         *[Revenues](#Revenue1)
#         *[Earnings](#Earning1)
#         *[Dividends](#Dividend1)
#     * [Exponantial model](#Exponential_Model)
#         *[Revenues](#Revenue2)
#         *[Earnings](#Earning2)
#         *[Dividends](#Dividend2)
#     * [Power Curve model](#PowerCurve_Model)
#         *[Revenues](#Revenue3)
#         *[Earnings](#Earning3)
#         *[Dividends](#Dividend3)
#
# * Author: Gerti Kulla
# * Class: Brooklyn College/Cisc7700X
# * Semester: Fall 2024

# %% [markdown]
# # Homework#1

# %% [markdown]
# CISC 7700X HW# 1 (due by 2nd class;): Using the Iris dataset, build a kNN model to identify the IRIS species of a flower given sepal_length, sepal_width, petal_length,petal_width. Feel free to use whatever language/tool you are comfortable with. I encourage you to write C/C++/Java/C#/SQL/Python code. You may also use Excel, or Weka or Colab or whatever other library/tool you find. Submit (via email), the model code.

# %% [markdown]
# ## Import_Packages

# %%
# !pip install seaborn scipy
# !pip install -U scikit-learn
# !pip install statsmodels

import sys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from statsmodels.stats.power import TTestIndPower 
from scipy.stats import bootstrap
# %matplotlib inline

# %% [markdown]
# ## Data_Load

# %%
#Reading excel data into DataFrame

df = pd.read_csv(r'http://theparticle.com/cs/bc/dsci/iris.csv')

#Creating a new df with 3 row values to use for test predictions
PredictionSet = df.iloc[[47]]
PredictionSet = pd.concat([df.iloc[[82]], PredictionSet], axis=0, ignore_index=True)
PredictionSet = pd.concat([df.iloc[[147]], PredictionSet], axis=0, ignore_index=True)

#Respective record indexes are removed
df = df.drop(df.index[[47,82,147]])

# %% [markdown]
# ## DataFrame_Statistics

# %%
df.describe().loc[['mean','std','25%', '75%']]
# Out:
#       sepal_length  sepal_width  petal_length  petal_width
# mean      5.847619     3.055782      3.763946     1.200000
# std       0.828378     0.436852      1.767668     0.763643
# 25%       5.100000     2.800000      1.600000     0.300000
# 75%       6.400000     3.300000      5.100000     1.800000

# %% [markdown]
# ## DataFrame_Formating

# %%
#keeping values with no headers actual values [X] and target values [Y]
X = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']][1:]
Y = df['species'][1:] 

X_training, X_testing, Y_training, Y_testing = train_test_split(X, Y, test_size=0.2, random_state=23)

# %% [markdown]
# ## KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors=8).fit(X_training,Y_training)
model
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
model.score(X_training, Y_training)
# Out:
# 0.9827586206896551

# %%
X_training.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    116.000000   116.000000    116.000000   116.000000
# mean       5.891379     3.025862      3.920690     1.268966
# std        0.839002     0.456093      1.749957     0.760139
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.175000     2.700000      1.675000     0.400000
# 50%        5.800000     3.000000      4.500000     1.400000
# 75%        6.400000     3.225000      5.150000     1.900000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Predictions

# %%
print(f"Original: {PredictionSet.iloc[[0]]['species']}")

prediction1 = model.predict([[6.5,3.0,5.2,2.0]])
print(f"Prediction: {prediction1}")
# Out:
# Original: 0    virginica
# Name: species, dtype: object
# Prediction: ['virginica']
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print(f"Original: {PredictionSet.iloc[[1]]['species']}")
      
prediction2 = model.predict([[5.8,2.7,3.9,1.2]])
print(f"Prediction: {prediction2}")
# Out:
# Original: 1    versicolor
# Name: species, dtype: object
# Prediction: ['versicolor']
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
print(f"Original: {PredictionSet.iloc[[2]]['species']}")
      
prediction3 = model.predict([[4.6,3.2,1.4,0.2]])
print(f"Prediction: {prediction3}")
# Out:
# Original: 2    setosa
# Name: species, dtype: object
# Prediction: ['setosa']
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
#Plot pairwise relationships in IRIS dataset
g = sns.pairplot(df, hue='species', markers='*', kind='reg', height=2)

# %%
#implementing predict_species function based on above plot
sample_test2 = [4.6,3.2,1.4,0.2]  #setosa
sample_test1 = [5.8,2.7,3.9,1.2]  #versicolor
sample_test = [6.5,3.0,5.2,2.0]   #virginica

def predict_species(sample):
    predicted_species = ""
    
    for sample_test in sample:
        if(sample_test[0] <= 4.3 or sample_test[1] > 3.8 or sample_test[2] <= 2.2 or sample_test[3] < 0.8):
            predicted_species = "setosa"
        elif(sample_test[0] >= 7.2 or sample_test[2] >= 5.2):
            predicted_species = "virginica"
        elif(sample_test[2] > 2.2 and sample_test[2] < 5.2 and sample_test[3] >= 0.8 and sample_test[3] < 1.2):
            predicted_species = "versicolor"
        #mixed area
        elif(sample_test[0] > 4.3 and sample_test[0] < 6):
            if(sample_test[2] >= 3 and sample_test[2] <= 5):
                predicted_species = "versicolor"
            elif(sample_test[2] <= 5):
                predicted_species = "virginica"

        print(f"Predicted species: {predicted_species}")

list = [[6.5,3.0,5.2,2.0],[5.8,2.7,3.9,1.2],[4.6,3.2,1.4,0.2]]    
predict_species(list)

print("---------------------------")
print(f"Original: {PredictionSet.iloc[[0]]['species']}")
print(f"Original: {PredictionSet.iloc[[1]]['species']}")
print(f"Original: {PredictionSet.iloc[[2]]['species']}")
# Out:
# Predicted species: virginica
# Predicted species: versicolor
# Predicted species: setosa
# ---------------------------
# Original: 0    virginica
# Name: species, dtype: object
# Original: 1    versicolor
# Name: species, dtype: object
# Original: 2    setosa
# Name: species, dtype: object

# %%
plt.figure(figsize=(7,4)) 
sns.heatmap(X.corr(), annot=True)
plt.show()

# %% [markdown]
# # Homework#2

# %% [markdown]
# CISC 7700X HW# 2: Continuing with the Iris dataset, plot the histograms for each of the attributes: sepal_length, sepal_width, petal_length, petal_width. Find the average and standard deveation for sepal_length, sepal_width, petal_length, petal_width for each label. Find the median and IQR for sepal_length, sepal_width, petal_length, petal_width for each label. Use bootstrap method to find error bounds on all of the above.

# %% [markdown]
# ## Histograms

# %%
df_noHeader=df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']][1:]
fig, axis = plt.subplots(2, 2, figsize = (25, 10))
df_noHeader.hist(ax=axis, color = "red", edgecolor='black', grid=True, bins = 40)
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %% [markdown]
# ## Mean_STD

# %%
def Q1(x):
    return x.quantile(0.25)

def Q3(x):
    return x.quantile(0.75)

X_data = df[1:][['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
Y_data = df[1:][['species']]
df_tot = pd.concat([X_data, Y_data], axis=1)

df_tot1 = df_tot.groupby('species').agg({'sepal_length': ['mean', 'std', 'median', Q1, Q3]})
df_tot2 = df_tot.groupby('species').agg({'sepal_width': ['mean', 'std', 'median', Q1, Q3]})
df_tot3 = df_tot.groupby('species').agg({'petal_length': ['mean', 'std', 'median', Q1, Q3]})
df_tot4 = df_tot.groupby('species').agg({'petal_width': ['mean', 'std', 'median', Q1, Q3]})
print(df_tot1, df_tot2, df_tot3, df_tot4)
# Out:
#            sepal_length
#                    mean       std median   Q1   Q3
# species
# setosa         5.012500  0.354680    5.0  4.8  5.2
# versicolor     5.938776  0.521143    5.9  5.6  6.3
# virginica      6.589796  0.642341    6.5  6.2  6.9            sepal_width
#                   mean       std median   Q1   Q3
# species
# setosa        3.420833  0.387550    3.4  3.1  3.7
# versicolor    2.771429  0.316886    2.8  2.5  3.0
# virginica     2.973469  0.325817    3.0  2.8  3.2            petal_length
#                    mean       std median   Q1   Q3
# species
# setosa         1.466667  0.176651    1.5  1.4  1.6
# versicolor     4.267347  0.471870    4.4  4.0  4.6
# virginica      5.559184  0.555247    5.6  5.1  5.9            petal_width
#                   mean       std median   Q1   Q3
# species
# setosa        0.245833  0.109074    0.2  0.2  0.3
# versicolor    1.328571  0.198956    1.3  1.2  1.5
# virginica     2.026531  0.277470    2.0  1.8  2.3

# %%
X_data=df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']][1:]

col_median = X_data.median()
col_std = X_data.std()
col_mean = X_data.mean()
col_quantile_25 = X_data.quantile(0.25)
col_quantile_75 = X_data.quantile(0.75)
IQR = col_quantile_75 - col_quantile_25
IQR
# Out:
# sepal_length    1.3
# sepal_width     0.5
# petal_length    3.5
# petal_width     1.5
# dtype: float64

# %%
print(f"Mean & STD for Sepal-Length:\n{round((X['sepal_length'].describe().loc[['mean','std']]),4)}")
# Out:
# Mean & STD for Sepal-Length:
# mean    5.8527
# std     0.8289
# Name: sepal_length, dtype: float64

# %%
print(f"Mean & STD for Sepal-Width:\n{round((X['sepal_width'].describe().loc[['mean','std']]),4)}")
# Out:
# Mean & STD for Sepal-Width:
# mean    3.0527
# std     0.4368
# Name: sepal_width, dtype: float64

# %%
print(f"Mean & STD for Petal-Lenght:\n{round((X['petal_length'].describe().loc[['mean','std',]]),4)}")
# Out:
# Mean & STD for Petal-Lenght:
# mean    3.7801
# std     1.7628
# Name: petal_length, dtype: float64

# %%
print(f"Mean & STD for Petal-Width:\n{round((X['petal_width'].describe().loc[['mean','std']]),4)}")
# Out:
# Mean & STD for Petal-Width:
# mean    1.2068
# std     0.7617
# Name: petal_width, dtype: float64

# %% [markdown]
# ## Median_IQR

# %%
print(f"Median for Sepal-Length: {X['sepal_length'].median():.2f}")
# Out:
# Median for Sepal-Length: 5.80

# %%
Q1_SL = X['sepal_length'].quantile(0.25)
Q3_SL = X['sepal_length'].quantile(0.75)
IQR_SL = Q3_SL - Q1_SL
print(f"IQR for Sepal-Length: {round(IQR_SL,2)}")
# Out:
# IQR for Sepal-Length: 1.3

# %%
print(f"Median for Sepal-Lenght: {X['sepal_width'].median():.2f}")
# Out:
# Median for Sepal-Lenght: 3.00

# %%
Q1_SL = X['sepal_width'].quantile(0.25)
Q3_SL = X['sepal_width'].quantile(0.75)
IQR_SL = Q3_SL - Q1_SL
print(f"IQRL for Sepal-Lenght: {round(IQR_SL,2)}")
# Out:
# IQRL for Sepal-Lenght: 0.5

# %%
print(f"Median for Petal-Lenght: {X['petal_length'].median():.2f}")
# Out:
# Median for Petal-Lenght: 4.40

# %%
Q1_SL = X['petal_length'].quantile(0.25)
Q3_SL = X['petal_length'].quantile(0.75)
IQR_SL = Q3_SL - Q1_SL
print(f"IQR for Petal-Lenght: {IQR_SL:.2f}")
# Out:
# IQR for Petal-Lenght: 3.50

# %%
print(f"Median for Petal-Length: {X['petal_width'].median():.2f}")
# Out:
# Median for Petal-Length: 1.30

# %%
Q1_SL = X['petal_width'].quantile(0.25)
Q3_SL = X['petal_width'].quantile(0.75)
IQR_SL = Q3_SL - Q1_SL
print(f"IQR for Petal-Width: {IQR_SL:.2f}")
# Out:
# IQR for Petal-Width: 1.50

# %%
# Plot histogram of versicolor petal lengths
values, bins, bars = plt.hist(df['sepal_length'], edgecolor='yellow')
plt.bar_label(bars, fontsize=7, color='navy')
values, bins, bars = plt.hist(df['sepal_width'], edgecolor='red', color='orange')
plt.bar_label(bars, fontsize=7, color='orange')
values, bins, bars = plt.hist(df['petal_length'], edgecolor='blue', color='white')
plt.bar_label(bars, fontsize=7, color='black')
values, bins, bars = plt.hist(df['petal_width'], edgecolor='black', color='brown')
plt.bar_label(bars, fontsize=7, color='brown')
plt.xlabel("Species")
plt.ylabel("Count")
plt.title('IRIS dataset') 
plt.grid()
plt.show()

# %%
df.plot(kind='line', grid=True)
sys.stdout.flush()

# %% [markdown]
# ## Bootstrap_Method

# %%
upperQ = []
lowerQ = []

x = X['petal_width']
subsample = x.sample(frac=1, replace=True)

for i in range(1000):
    subsample = x.sample(frac=1, replace=True)
    upperQ.append(subsample.quantile(0.99))
    lowerQ.append(subsample.quantile(0.01))

upperQ = pd.Series(upperQ)
lowerQ = pd.Series(lowerQ)

plt.subplot(1,2,1)
plt.title('Upper quantiles')
plt.hist(upperQ, bins = 8)
plt.grid()

plt.subplot(1,2,2)
plt.title('Lower quantiles') 
plt.hist(lowerQ, bins = 8)
plt.grid()

# %%
print("upper 0.99 quantile lies in this interval with 95% confidence")
print(f"2.5% quantile: {upperQ.quantile(0.025):.2f} 97.5% quantile: {upperQ.quantile(0.975):.2f}")

print("lower 0.01 quantile lies in this interval with 95% confidence")
print(f"2.5% quantile: {lowerQ.quantile(0.025):.2f} 97.5% quantile: {lowerQ.quantile(0.975):.2f}")
# Out:
# upper 0.99 quantile lies in this interval with 95% confidence
# 2.5% quantile: 2.36 97.5% quantile: 2.50
# lower 0.01 quantile lies in this interval with 95% confidence
# 2.5% quantile: 0.10 97.5% quantile: 0.15

# %%
#using boostrap function
data = x.to_numpy()
data = (data,)

print("95% confidentce interval")
bootstrap_ci = bootstrap(data, np.std, confidence_level=0.95, random_state=1, method='percentile')

print(bootstrap_ci.confidence_interval)
# Out:
# 95% confidentce interval
# ConfidenceInterval(low=np.float64(0.7039359361001531), high=np.float64(0.8057827945454547))

# %%
upperQ = []
lowerQ = []

x = X['petal_length']
subsample = x.sample(frac=1, replace=True)

for i in range(1000):
    subsample = x.sample(frac=1, replace=True)
    upperQ.append(subsample.quantile(0.99))
    lowerQ.append(subsample.quantile(0.01))

upperQ = pd.Series(upperQ)
lowerQ = pd.Series(lowerQ)

plt.subplot(1,2,1)
plt.title('Upper quantiles')
plt.hist(upperQ, bins = 8)
plt.grid()

plt.subplot(1,2,2)
plt.title('Lower quantiles') 
plt.hist(lowerQ, bins = 8)
plt.grid()

# %%
print("upper 0.99 quantile lies in this interval with 95% confidence")
print(f"2.5% quantile: {upperQ.quantile(0.025):.2f} 97.5% quantile: {upperQ.quantile(0.975):.2f}")

print("lower 0.01 quantile lies in this interval with 95% confidence")
print(f"2.5% quantile: {lowerQ.quantile(0.025):.2f} 97.5% quantile: {lowerQ.quantile(0.975):.2f}")
# Out:
# upper 0.99 quantile lies in this interval with 95% confidence
# 2.5% quantile: 6.21 97.5% quantile: 6.90
# lower 0.01 quantile lies in this interval with 95% confidence
# 2.5% quantile: 1.00 97.5% quantile: 1.30

# %%
#using boostrap function
data = x.to_numpy()
data = (data,)

print("95% confidentce interval")
bootstrap_ci = bootstrap(data, np.std, confidence_level=0.95,random_state=1, method='percentile')

print(bootstrap_ci.confidence_interval)
# Out:
# 95% confidentce interval
# ConfidenceInterval(low=np.float64(1.6335884088763204), high=np.float64(1.856727786596656))

# %%
upperQ = []
lowerQ = []

x = X['sepal_length']
subsample = x.sample(frac=1, replace=True)

for i in range(1000):
    subsample = x.sample(frac=1, replace=True)
    upperQ.append(subsample.quantile(0.99))
    lowerQ.append(subsample.quantile(0.01))

upperQ = pd.Series(upperQ)
lowerQ = pd.Series(lowerQ)

plt.subplot(1,2,1)
plt.title('Upper quantiles')
plt.hist(upperQ, bins = 8)
plt.grid()

plt.subplot(1,2,2)
plt.title('Lower quantiles') 
plt.hist(lowerQ, bins = 8)
plt.grid()

# %%
print("upper 0.99 quantile lies in this interval with 95% confidence")
print(f"2.5% quantile: {upperQ.quantile(0.025):.2f} 97.5% quantile: {upperQ.quantile(0.975):.2f}")

print("lower 0.01 quantile lies in this interval with 95% confidence")
print(f"2.5% quantile: {lowerQ.quantile(0.025):.2f} 97.5% quantile: {lowerQ.quantile(0.975):.2f}")
# Out:
# upper 0.99 quantile lies in this interval with 95% confidence
# 2.5% quantile: 7.42 97.5% quantile: 7.90
# lower 0.01 quantile lies in this interval with 95% confidence
# 2.5% quantile: 4.30 97.5% quantile: 4.60

# %%
data = x.to_numpy()
data = (data,)

print("95% confidentce interval")
bootstrap_ci = bootstrap(data, np.std, confidence_level=0.95,random_state=1, method='percentile')

print(bootstrap_ci.confidence_interval)
# Out:
# ConfidenceInterval(low=np.float64(0.7425576169413477), high=np.float64(0.9027013860058574))

# %%
upperQ = []
lowerQ = []

x = X['sepal_width']
subsample = x.sample(frac=1, replace=True)

for i in range(1000):
    subsample = x.sample(frac=1, replace=True)
    upperQ.append(subsample.quantile(0.99))
    lowerQ.append(subsample.quantile(0.01))

upperQ = pd.Series(upperQ)
lowerQ = pd.Series(lowerQ)

plt.subplot(1,2,1)
plt.title('Upper quantiles')
plt.hist(upperQ, bins = 8)
plt.grid()

plt.subplot(1,2,2)
plt.title('Lower quantiles') 
plt.hist(lowerQ, bins = 8)
plt.grid()

# %%
print("upper 0.99 quantile lies in this interval with 95% confidence")
print(f"2.5% quantile: {upperQ.quantile(0.025):.2f} 97.5% quantile: {upperQ.quantile(0.975):.2f}")

print("lower 0.01 quantile lies in this interval with 95% confidence")
print(f"2.5% quantile: {lowerQ.quantile(0.025):.2f} 97.5% quantile: {lowerQ.quantile(0.975):.2f}")
# Out:
# upper 0.99 quantile lies in this interval with 95% confidence
# 2.5% quantile: 3.86 97.5% quantile: 4.40
# lower 0.01 quantile lies in this interval with 95% confidence
# 2.5% quantile: 2.00 97.5% quantile: 2.30

# %%
#using boostrap function
data = x.to_numpy()
data = (data,)

print("95% confidentce interval")
bootstrap_ci = bootstrap(data, np.std, confidence_level=0.95,random_state=1, method='percentile')

print(bootstrap_ci.confidence_interval)
# Out:
# 95% confidentce interval
# ConfidenceInterval(low=np.float64(0.379883631082617), high=np.float64(0.4863384125694891))

# %% [markdown]
# # Homework#3

# %% [markdown]
# CISC 7700X HW# 3: We have a labeled training data set: hw3.data1.csv.gz.
# Thinking of a linear model, we come up with:
#
# y = 24*column1 + -15*column2 + -38*column3 + -7*column4 + -41*column5 + 35*column6 + 0*column7 + -2*column8 + 19*column9 + 33*column10 + -3*column11 + 7*column12 + 3*column13 + -47*column14 + 26*column15 + 10*column16 + 40*column17 + -1*column18 + 3*column19 + 0*column20 + -6
#
# if y is > 0 then 1 othewise -1.
#
# What is the accuracy? Calculate the confusion matrix for this model. If cost of a false negative is $1000, and cost of a false positive is $100, (and $0 for an accurate answer), what is the expected economic gain?
#
# How can we tweak the model to increase economic gain? Come up with a model that maximizes economic gain (approximations are OK; try guestimating a few possibilities in a spreadsheet, etc.).
#
# Email the numbers and the steps you used to calculate things (you can do most of this homework in a spreadsheet [Excel?], but I highly encourage you to write code---learn Python if not sure where to start).

# %% [markdown]
# ## Data_model_load

# %%
df = pd.read_csv('http://theparticle.com/cs/bc/dsci/hw3.data1.csv.gz', compression='gzip')

print(df.head())
# Out:
#    column1  column2  column3  column4  column5  column6  column7  column8  \
# 0      -40      -31       36      -43       52       10      -31       41
# 1       42      -42      -37       49       33       34       -4       -2
# 2      -28      -19      -27       -4       42      -37      -38      -22
# 3      -44        0       20      -28       -5       28       15      -41
# 4       46        9        8      -10       27       34      -25       11
#
#    column9  column10  ...  column12  column13  column14  column15  column16  \
# 0      -31        -6  ...         8        37       -30        34       -15
# 1       50        10  ...        -8         7       -50        16         9
# 2      -27       -36  ...       -31        29       -12        -6        31
# 3      -13        32  ...       -38       -30       -52        37       -22
# 4       47       -18  ...        23       -47       -25        -4        11
#
#    column17  column18  column19  column20  label
# ...

# %% [markdown]
# ## Calculate_data_model

# %%
def compute_model_values(dataframe):
    X_actual = []

    for index, row in dataframe.iterrows():
        result = 24*row['column1'] -15*row['column2'] -38*row['column3'] -7*row['column4'] -41*row['column5'] + 35*row['column6'] + 0*row['column7'] -2*row['column8'] + 19*row['column9'] + 33*row['column10'] -3*row['column11'] + 7*row['column12'] + 3*row['column13'] -47*row['column14'] + 26*row['column15'] + 10*row['column16'] + 40*row['column17'] -1*row['column18'] + 3*row['column19'] + 0*row['column20'] -6
        if result > 1:
            X_actual.append(1)
        else:
            X_actual.append(-1)

    return pd.DataFrame(X_actual, columns=['X_data'])  

X_actual_df = compute_model_values(df)
print(X_actual_df)
# Out:
#       X_data
# 0         -1
# 1          1
# 2         -1
# 3          1
# 4          1
# ...      ...
# 9995       1
# 9996       1
# 9997       1
# 9998      -1
# 9999       1
#
# [10000 rows x 1 columns]

# %% [markdown]
# ## Calculate_TP_TN_FP_FN

# %%
Y_actual_df = df['label']

df3 = pd.concat([X_actual_df, Y_actual_df], axis=1)

def compute_model(X_actual_df, Y_actual_df):
    records = 10000
    match = TP = TN = FP = FN = 0

    for _, row in df3.iterrows():
        if( row['X_data'] == row['label'] and row['X_data'] > 0):
            TP += 1;
            match += 1;
        elif( row['X_data'] == row['label'] and row['X_data'] < 0):
            TN += 1;
            match += 1;
        elif( row['X_data'] > 0 and row['label'] < 0):
            FP += 1;
        elif( row['X_data'] < 0 and row['label'] > 0):
            FN += 1;

    return match, TP, TN, FP, FN

result = compute_model(X_actual_df, Y_actual_df)

TP=result[1]
TN=result[2]
FP=result[3]
FN=result[4]

print(f"match: {result[0]}, True positive: {result[1]}, True negative: {result[2]}, False positive: {result[3]*100}, False negative : {result[4]*1000}")
# Out:
# match: 8808, True positive: 3549, True negative: 5259, False positive: 48400, False negative : 708000

# %% [markdown]
# ## Model_Accuracy

# %%
#model accuracy
accuracy = (TP+TN)/(TP+TN+FP+FN)
print(accuracy)
# Out:
# 0.8808

# %% [markdown]
# ## Model_Precission

# %%
#model precision

precision = TP/(TP+FP)
print(precision)
# Out:
# 0.8799900818249442

# %% [markdown]
# ## Confusion_Matrix

# %%
conf_matrix = confusion_matrix(df3['X_data'],df3['label'])

# %%
sns.heatmap(conf_matrix, annot=True, fmt='g', xticklabels=['True','False'], yticklabels=['True','False']) 
plt.title('Confusion Matrix', fontsize=13, pad=10)
plt.xlabel('Prediction', fontsize=13)
plt.ylabel('Actual', fontsize=13) 
plt.show()

# %%
#False positive: 48400
#False negative : 708000

Economic_Gain = (TP+TN)*0 - (FP*100 + FN*1000)
print(Economic_Gain)
# Out:
# -756400

# %%
#tweaking the model to get better economic gain
def compute_modified_model(dataframe):
    X_actual = []

    for index, row in dataframe.iterrows():
        result = 24*row['column1'] -15*row['column2'] -38*row['column3'] -7*row['column4'] -41*row['column5'] + 35*row['column6'] + 0*row['column7'] -2*row['column8'] + 19*row['column9'] + 33*row['column10'] -3*row['column11'] + 7*row['column12'] + 3*row['column13'] -47*row['column14'] + 26*row['column15'] + 10*row['column16'] + 40*row['column17'] -1*row['column18'] + 3*row['column19'] + 0*row['column20'] +80
        if result > 1:
            X_actual.append(1)
        else:
            X_actual.append(-1)

    return pd.DataFrame(X_actual, columns=['X_data']) 

def compute_model(X_actual_df, Y_actual_df):
    df3 = pd.concat([X_actual_df, Y_actual_df], axis=1)

    records = 10000
    match = TP = TN = FP = FN = 0

    for _, row in df3.iterrows():
        if( row['X_data'] == row['label'] and row['X_data'] > 0):
            TP += 1;
            match += 1;
        elif( row['X_data'] == row['label'] and row['X_data'] < 0):
            TN += 1;
            match += 1;
        elif( row['X_data'] > 0 and row['label'] < 0):
            FP += 1;
        elif( row['X_data'] < 0 and row['label'] > 0):
            FN += 1;

    return match, TP, TN, FP, FN

X_actual_df = compute_modified_model(df)
result = compute_model(X_actual_df, Y_actual_df)
Economic_Gain = (result[1]+result[2])*0 - (result[3]*100 + result[4]*1000) #= 0 - 48400 - 708000 = -756400
print(f"Economic Gain: {Economic_Gain}")
# Out:
# Economic Gain: -684800

# %%
x_1 = np.array([-100, -80, -70, -50, -30, -15, -6, 0, 6, 15, 30, 50, 70, 80, 100])
y_1 = np.array([-846400,-829900,-819900,-802400,-782200,-767900, -756400, -753100, -744500,-741100,-726100,-709000, -697500,-684800,-672700])
plt.title("Economic Gain")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x_1, y_1, color="red", marker="o", label="Constant model flactuation")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # Homework#4

# %% [markdown]
# CISC 7700X HW# 4: Using data from anywhere on the internet, using previous 1 or 2 years data (excluding latest quarter!), build a linear [y = a+bx ], logarithmic [y = a+b*log(x) ], exponential [ y=b*exp(a*x) ], and power curve [ y=b*x^a ] models on revenue, earnings, and dividends, for symbols IBM, MSFT, AAPL, GOOG, FB, PG, GE.
#
# Which model works best for which metric/symbol? Show with numbers, (e.g. r-squared score, etc.). Read through: Coefficient of determination.
#
# Using the best model for each metric, make a prediction for `next quarter' revenue, earnings, and dividends. Remember, you didn't use the last number to build your models. Compare your model's prediction to the last quarter number. What's the error?
#
# Note: I used to suggest stockrow.com, but it seems they no longer let you get the data without payment. Same story with finance.yahoo.com. This data is available in LOTS of places through---SEC Edgar has it free... but you'll need to aggregate it across multiple reports. See if you can find another source for this data. It's public, it's out there, so find it. Or just grab last 8 quarterly reports from SEC Edgar (the 10Q reports).

# %% [markdown]
# ## Linear_Model

# %% [markdown]
# ### Revenue

# %%
#Linear data model for 7 secueiries
x=["Q4Dec-21","Q3Sep-21","Q2Jun-21","Q1Mar-21","Q4Dec-22","Q3Sep-22","Q2Jun-22","Q1Mar-22","Q4Dec-23","Q3Sep-23","Q2Jun-23","Q1Mar-23","Q2Jun-24","Q1Mar-24"]

#convert quarterly dates in numbers as ref to array x data
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM= np.array([16.69,13.25,14.22,13.19,16.69,14.11,15.54,14.2,17.38,14.75,15.48,14.25,15.77,14.46])
y_MSFT=np.array([64.73, 61.86, 56.19, 52.86, 52.75, 50.12, 51.86, 49.36, 51.73, 45.32, 51.86, 45.32, 46.15, 41.7])
y_AAPL=np.array([85.78, 90.75, 89.50, 81.80, 82.96, 94.84, 90.15, 82.96, 97.28, 123.94, 83.36, 81.43, 89.58, 111.43])
y_GOOG=np.array([84.74, 80.54, 86.31, 76.69, 74.60, 69.79, 76.05, 69.09, 69.68, 68.01, 75.32, 65.12, 61.88, 55.31])
y_FB=np.array([39.07, 38.79, 32.17, 27.71, 29.08, 28.65, 33.67, 29.01, 28.82, 27.91, 33.67, 29.01, 28.82, 27.91])
y_PG=np.array([18.00, 18.10, 19.60, 20.10, 19.20, 19.60, 20.70, 21.10, 20.00, 20.50, 20.70, 20.90, 20.53, 20.35])#, 20.20, 20.50])
y_GE=np.array([9.093, 8.938, 8.367, 7.954, 8.813, 8.675, 8.367, 5.810, 6.576, 6.675, 6.900, 5.469, 7.904, 7.863])#, 7.414, 7.833, 8.061, 8.892, 9.502])

#find line of best fit
a_IBM, b_IBM = np.polyfit(x, y_IBM, 1)
a_MSFT, b_MSFT = np.polyfit(x, y_MSFT, 1)
a_AAPL, b_AAPL = np.polyfit(x, y_AAPL, 1)
a_GOOG, b_GOOG = np.polyfit(x, y_GOOG, 1)
a_FB, b_FB = np.polyfit(x, y_FB, 1)
a_PG, b_PG = np.polyfit(x, y_PG, 1)
a_GE, b_GE = np.polyfit(x, y_GE, 1)

#add points to plot
plt.subplot(4,2,1)
plt.title('IBM')
plt.scatter(x, y_IBM, color="purple")
plt.plot(x, a_IBM*x+b_IBM, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,2)
plt.title('Micorsoft')
plt.scatter(x, y_MSFT, color="purple")
plt.plot(x, a_MSFT*x+b_MSFT, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,3)
plt.title('Apple')
plt.scatter(x, y_AAPL, color="purple")
plt.plot(x, a_AAPL*x+b_AAPL, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,4)
plt.title('Google')
plt.scatter(x, y_GOOG, color="purple")
plt.plot(x, a_GOOG*x+b_GOOG, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,5)
plt.title('FaceBook')
plt.scatter(x, y_FB, color="purple")
plt.plot(x, a_FB*x+b_FB, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,6)
plt.title('PG')
plt.scatter(x, y_PG, color="purple")
plt.plot(x, a_PG*x+b_PG, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,7)
plt.title('General Electric')
plt.scatter(x, y_GE, color="purple")
plt.plot(x, a_GE*x+b_GE, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.tight_layout()

# %%
#linear model predictions for each of securitites
x=53

print("Expected last quarterly IBM value: 14.46 Billion")
y=a_IBM*x+b_IBM
print(f"Predicted linear model value: {y:.2f} Billion | Error: {(14.46 - y):.2f} Billion")

print("Expected last quarterly MSFT value: 41.7 Billion")
y=a_MSFT*x+b_MSFT
print(f"Predicted linear model value: {y:.2f} Billion | Error: {(41.7 - y):.2f} Billion")

print("Expected last quarterly AAPL value: 111.43 Billion")
y=a_AAPL*x+b_AAPL
print(f"Predicted linear model value: {y:.2f} Billion | Error: {(111.43 - y):.2f} Billion")

print("Expected last quarterly GOOG value: 55.31 Billion")
y=a_GOOG*x+b_GOOG
print(f"Predicted linear model value: {y:.2f} Billion | Error: {(55.31 - y):.2f} Billion")

print("Expected last quarterly FB value: 27.91 Billion")
y=a_FB*x+b_FB
print(f"Predicted linear model value: {y:.2f} Billion | Error: {(27.91 - y):.2f} Billion")

print("Expected last quarterly PG value: 20.35 Billion")
y=a_PG*x+b_PG
print(f"Predicted linear model value: {y:.2f} Billion | Error: {(20.35 - y):.2f} Billion")

print("Expected last quarterly GE value: 7.863 Billion")
y=a_GE*x+b_GE
print(f"Predicted linear model value: {y:.2f} Billion | Error: {(7.863 - y):.2f} Billion")
# Out:
# Expected last quarterly IBM value: 14.46 Billion
# Predicted linear model value: 15.20 Billion | Error: -0.74 Billion
# Expected last quarterly MSFT value: 41.7 Billion
# Predicted linear model value: 42.82 Billion | Error: -1.12 Billion
# Expected last quarterly AAPL value: 111.43 Billion
# Predicted linear model value: 98.47 Billion | Error: 12.96 Billion
# Expected last quarterly GOOG value: 55.31 Billion
# Predicted linear model value: 60.53 Billion | Error: -5.22 Billion
# Expected last quarterly FB value: 27.91 Billion
# Predicted linear model value: 27.43 Billion | Error: 0.48 Billion
# Expected last quarterly PG value: 20.35 Billion
# Predicted linear model value: 21.12 Billion | Error: -0.77 Billion
# Expected last quarterly GE value: 7.863 Billion
# Predicted linear model value: 6.52 Billion | Error: 1.34 Billion

# %% [markdown]
# ### Earning

# %%
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM=np.array([3.48, 3.73, 2.91, 3.60,3.31, 2.59, 3.36, 3.34,3.60, 2.29, 2.56, 3.39,2.77, 2.80]) #, 2.77, 1.77]
y_MSFT=np.array([2.69, 2.50, 2.32, 2.69,2.69, 2.45, 2.48, 2.17,2.23, 1.95, 2.48, 2.17,2.03, 1.95])
y_AAPL=np.array([1.30, 1.43, 1.24, 1.40,1.41, 1.20, 1.18, 1.17,1.25, 1.40, 1.18, 1.24,1.18, 1.40])
y_GOOG=np.array([1.59, 1.25, 1.38, 1.06,1.56, 1.11, 1.44, 1.17,1.25, 1.20, 1.55, 1.51,1.76, 1.27])
y_FB=np.array([2.99, 2.92, 2.80, 2.68,2.72, 2.60, 2.53, 1.88,2.28, 1.76, 2.02, 1.95,2.01, 1.78])
y_PG=np.array([1.43, 1.38, 1.37, 1.33,1.32, 1.28, 1.24, 1.22,1.23, 1.22, 1.14, 1.10,1.03, 1.06])
y_GE=np.array([0.38, 0.31, 0.32, 0.24,0.28, 0.23, 0.21, 0.18,0.15, 0.12, 0.09, 0.07,0.05, 0.06])

#find line of best fit
a_IBM, b_IBM = np.polyfit(x, y_IBM, 1)
a_MSFT, b_MSFT = np.polyfit(x, y_MSFT, 1)
a_AAPL, b_AAPL = np.polyfit(x, y_AAPL, 1)
a_GOOG, b_GOOG = np.polyfit(x, y_GOOG, 1)
a_FB, b_FB = np.polyfit(x, y_FB, 1)
a_PG, b_PG = np.polyfit(x, y_PG, 1)
a_GE, b_GE = np.polyfit(x, y_GE, 1)

#add points to plot
plt.subplot(4,2,1)
plt.title('IBM')
plt.scatter(x, y_IBM, color="purple")
plt.plot(x, a_IBM*x+b_IBM, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,2)
plt.title('Micorsoft')
plt.scatter(x, y_MSFT, color="purple")
plt.plot(x, a_MSFT*x+b_MSFT, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,3)
plt.title('Apple')
plt.scatter(x, y_AAPL, color="purple")
plt.plot(x, a_AAPL*x+b_AAPL, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,4)
plt.title('Google')
plt.scatter(x, y_GOOG, color="purple")
plt.plot(x, a_GOOG*x+b_GOOG, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,5)
plt.title('FaceBook')
plt.scatter(x, y_FB, color="purple")
plt.plot(x, a_FB*x+b_FB, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,6)
plt.title('PG')
plt.scatter(x, y_PG, color="purple")
plt.plot(x, a_PG*x+b_PG, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,7)
plt.title('General Electric')
plt.scatter(x, y_GE, color="purple")
plt.plot(x, a_GE*x+b_GE, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.tight_layout()

# %%
#linear model predictions for each of securitites
x=53

print("Expected last quarterly IBM value: 2.8")
y=a_IBM*x+b_IBM
print(f"Predicted linear model value: {y:.2f} | Error: {(2.8 - y):.2f}")

print("Expected last quarterly MSFT value: 1.95")
y=a_MSFT*x+b_MSFT
print(f"Predicted linear model value: {y:.2f} | Error: {(1.95 - y):.2f}")

print("Expected last quarterly AAPL value: 1.4")
y=a_AAPL*x+b_AAPL
print(f"Predicted linear model value: {y:.2f} | Error: {(1.4 - y):.2f}")

print("Expected last quarterly GOOG value: 1.27")
y=a_GOOG*x+b_GOOG
print(f"Predicted linear model value: {y:.2f} | Error: {(1.27 - y):.2f}")

print("Expected last quarterly FB value: 1.78")
y=a_FB*x+b_FB
print(f"Predicted linear model value: {y:.2f} | Error: {(1.78 - y):.2f}")

print("Expected last quarterly PG value: 1.06")
y=a_PG*x+b_PG
print(f"Predicted linear model value: {y:.2f} | Error: {(1.06 - y):.2f}")

print("Expected last quarterly GE value: 1.06")
y=a_GE*x+b_GE
print(f"Predicted linear model value: {y:.2f} | Error: {(1.06 - y):.2f}")
# Out:
# Expected last quarterly IBM value: 2.8
# Predicted linear model value: 2.77 | Error: 0.03
# Expected last quarterly MSFT value: 1.95
# Predicted linear model value: 2.02 | Error: -0.07
# Expected last quarterly AAPL value: 1.4
# Predicted linear model value: 1.24 | Error: 0.16
# Expected last quarterly GOOG value: 1.27
# Predicted linear model value: 1.43 | Error: -0.16
# Expected last quarterly FB value: 1.78
# Predicted linear model value: 1.72 | Error: 0.06
# Expected last quarterly PG value: 1.06
# Predicted linear model value: 1.05 | Error: 0.01
# Expected last quarterly GE value: 1.06
# Predicted linear model value: 0.03 | Error: 1.03

# %% [markdown]
# ### Dividend

# %%
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM=np.array([1.67,1.67, 1.67, 1.66,1.66, 1.66, 1.66, 1.65, 1.65, 1.65, 1.65, 1.64, 1.64, 1.64])#, 1.64, 1.63])
y_MSFT=np.array([0.83, 0.83, 0.75, 0.75,0.75, 0.75, 0.68, 0.68,0.62, 0.62, 0.56, 0.56,0.51, 0.51])#, 0.51, 0.51])
y_AAPL=np.array([0.25, 0.25, 0.24, 0.24,0.24, 0.24, 0.23, 0.23,0.23, 0.23, 0.23, 0.23,0.22, 0.22])#, 0.22])
y_PG=np.array([0.94, 0.94, 0.91, 0.91,0.91, 0.91, 0.87, 0.87,0.87, 0.87, 0.79, 0.79,0.79, 0.79])#, 0.75])
y_GE=np.array([0.08, 0.08, 0.08, 0.08,0.08, 0.08, 0.08, 0.08,0.01, 0.01, 0.01, 0.01,0.01, 0.01])#, 0.01])

#find line of best fit
a_IBM, b_IBM = np.polyfit(x, y_IBM, 1)
a_MSFT, b_MSFT = np.polyfit(x, y_MSFT, 1)
a_AAPL, b_AAPL = np.polyfit(x, y_AAPL, 1)
a_PG, b_PG = np.polyfit(x, y_PG, 1)
a_GE, b_GE = np.polyfit(x, y_GE, 1)

#add points to plot
plt.subplot(3,2,1)
plt.title('IBM')
plt.scatter(x, y_IBM, color="purple")
plt.plot(x, a_IBM*x+b_IBM, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,2)
plt.title('Micorsoft')
plt.scatter(x, y_MSFT, color="purple")
plt.plot(x, a_MSFT*x+b_MSFT, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,3)
plt.title('Apple')
plt.scatter(x, y_AAPL, color="purple")
plt.plot(x, a_AAPL*x+b_AAPL, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,4)
plt.title('PG')
plt.scatter(x, y_PG, color="purple")
plt.plot(x, a_PG*x+b_PG, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,5)
plt.title('General Electric')
plt.scatter(x, y_GE, color="purple")
plt.plot(x, a_GE*x+b_GE, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.tight_layout()

# %%
x=53

print("Expected last quarterly IBM value: 1.64")
y=a_IBM*x+b_IBM
print(f"Predicted linear model value: {y:.2f} | Error: {(1.64 - y):.2f}")

print("Expected last quarterly MSFT value: 0.51")
y=a_MSFT*x+b_MSFT
print(f"Predicted linear model value: {y:.2f} | Error: {(0.51 - y):.2f}")

print("Expected last quarterly AAPL value: 0.22")
y=a_AAPL*x+b_AAPL
print(f"Predicted linear model value: {y:.2f} | Error: {(0.22 - y):.2f}")

print("Expected last quarterly PG value: 0.79")
y=a_PG*x+b_PG
print(f"Predicted linear model value: {y:.2f} | Error: {(0.79 - y):.2f}")

print("Expected last quarterly GE value: 0.01")
y=a_GE*x+b_GE
print(f"Predicted linear model value: {y:.2f} | Error: {(0.01 - y):.2f}")
# Out:
# Expected last quarterly IBM value: 1.64
# Predicted linear model value: 1.64 | Error: 0.00
# Expected last quarterly MSFT value: 0.51
# Predicted linear model value: 0.50 | Error: 0.01
# Expected last quarterly AAPL value: 0.22
# Predicted linear model value: 0.22 | Error: -0.00
# Expected last quarterly PG value: 0.79
# Predicted linear model value: 0.79 | Error: 0.00
# Expected last quarterly GE value: 0.01
# Predicted linear model value: 0.00 | Error: 0.01

# %% [markdown]
# ## Logarithmic_Model

# %% [markdown]
# ### Revenue1

# %%
#logarithmic
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM= np.array([16.69,13.25,14.22,13.19,16.69,14.11,15.54,14.2,17.38,14.75,15.48,14.25,15.77,14.46])
y_MSFT=np.array([64.73, 61.86, 56.19, 52.86, 52.75, 50.12, 51.86, 49.36, 51.73, 45.32, 51.86, 45.32, 46.15, 41.7])
y_AAPL=np.array([85.78, 90.75, 89.50, 81.80, 82.96, 94.84, 90.15, 82.96, 97.28, 123.94, 83.36, 81.43, 89.58, 111.43])
y_GOOG=np.array([84.74, 80.54, 86.31, 76.69, 74.60, 69.79, 76.05, 69.09, 69.68, 68.01, 75.32, 65.12, 61.88, 55.31])
y_FB=np.array([39.07, 38.79, 32.17, 27.71, 29.08, 28.65, 33.67, 29.01, 28.82, 27.91, 33.67, 29.01, 28.82, 27.91])
y_PG=np.array([18.00, 18.10, 19.60, 20.10, 19.20, 19.60, 20.70, 21.10, 20.00, 20.50, 20.70, 20.90, 20.53, 20.35])#, 20.20, 20.50])
y_GE=np.array([9.093, 8.938, 8.367, 7.954, 8.813, 8.675, 8.367, 5.810, 6.576, 6.675, 6.900, 5.469, 7.904, 7.863])

x_log_IBM = np.log(x)

a_IBM, b_IBM = np.polyfit(x_log_IBM, y_IBM, 1)
a_MSFT, b_MSFT = np.polyfit(x_log_IBM, y_MSFT, 1)
a_AAPL, b_AAPL = np.polyfit(x_log_IBM, y_AAPL, 1)
a_GOOG, b_GOOG = np.polyfit(x_log_IBM, y_GOOG, 1)
a_FB, b_FB = np.polyfit(x_log_IBM, y_FB, 1)
a_PG, b_PG = np.polyfit(x_log_IBM, y_PG, 1)
a_GE, b_GE = np.polyfit(x_log_IBM, y_GE, 1)

y_log_IBM = a_IBM*x_log_IBM + b_IBM
y_log_MSFT = a_MSFT*x_log_IBM + b_MSFT
y_log_AAPL = a_AAPL*x_log_IBM + b_AAPL
y_log_GOOG = a_GOOG*x_log_IBM + b_GOOG
y_log_FB = a_FB*x_log_IBM + b_FB
y_log_PG = a_PG*x_log_IBM + b_PG
y_log_GE = a_GE*x_log_IBM + b_GE

plt.subplot(4,2,1)
plt.title('IBM')
plt.plot(x_log_IBM, y_IBM)
plt.plot(x_log_IBM,y_log_IBM)
plt.grid()

plt.subplot(4,2,2)
plt.title('Microsoft')
plt.plot(x_log_IBM, y_MSFT)
plt.plot(x_log_IBM,y_log_MSFT)
plt.grid()

plt.subplot(4,2,3)
plt.title('Apple')
plt.plot(x_log_IBM, y_AAPL)
plt.plot(x_log_IBM,y_log_AAPL)
plt.grid()

plt.subplot(4,2,4)
plt.title('Google')
plt.plot(x_log_IBM, y_GOOG)
plt.plot(x_log_IBM,y_log_GOOG)
plt.grid()

plt.subplot(4,2,5)
plt.title('Facebook')
plt.plot(x_log_IBM, y_FB)
plt.plot(x_log_IBM,y_log_FB)
plt.grid()

plt.subplot(4,2,6)
plt.title('PG')
plt.plot(x_log_IBM, y_PG)
plt.plot(x_log_IBM,y_log_PG)
plt.grid()

plt.subplot(4,2,7)
plt.title('General Electric')
plt.plot(x_log_IBM, y_GE)
plt.plot(x_log_IBM,y_log_GE)
plt.grid()

plt.tight_layout()

# %%
print(x_log_IBM[13])

print("Expected last quarterly IBM value: 14.46 Billion")
y_log_IBM = a_IBM*x_log_IBM[13] + b_IBM
print(f"Predicted linear model value: {y_log_IBM:.2f} Billion | Error: {(14.46 - y_log_IBM):.2f} Billion")

print("Expected last quarterly MSFT value: 41.7 Billion")
y_log_MSFT = a_MSFT*x_log_IBM[13] + b_MSFT
print(f"Predicted linear model value: {y_log_MSFT:.2f} Billion | Error: {(41.7 - y_log_MSFT):.2f} Billion")

print("Expected last quarterly AAPL value: 111.43 Billion")
y_log_AAPL = a_AAPL*x_log_IBM[13] + b_AAPL
print(f"Predicted linear model value: {y_log_AAPL:.2f} Billion | Error: {(111.43 - y_log_AAPL):.2f} Billion")

print("Expected last quarterly GOOG value: 55.31 Billion")
y_log_GOOG = a_GOOG*x_log_IBM[13] + b_GOOG
print(f"Predicted linear model value: {y_log_GOOG:.2f} Billion | Error: {(55.31 - y_log_GOOG):.2f} Billion")

print("Expected last quarterly FB value: 27.91 Billion")
y_log_FB = a_FB*x_log_IBM[13] + b_FB
print(f"Predicted linear model value: {y_log_FB:.2f} Billion | Error: {(27.91 - y_log_FB):.2f} Billion")

print("Expected last quarterly PG value: 20.35 Billion")
y_log_PG = a_PG*x_log_IBM[13] + b_PG
print(f"Predicted linear model value: {y_log_PG:.2f} Billion | Error: {(20.35 - y_log_PG):.2f} Billion")

print("Expected last quarterly GE value: 7.863 Billion")
y_log_GE = a_GE*x_log_IBM[13] + b_GE
print(f"Predicted linear model value: {y_log_GE:.2f} Billion | Error: {(7.863 - y_log_GE):.2f} Billion")
# Out:
# 3.970291913552122
# Expected last quarterly IBM value: 14.46 Billion
# Predicted linear model value: 14.95 Billion | Error: -0.49 Billion
# Expected last quarterly MSFT value: 41.7 Billion
# Predicted linear model value: 46.15 Billion | Error: -4.45 Billion
# Expected last quarterly AAPL value: 111.43 Billion
# Predicted linear model value: 95.05 Billion | Error: 16.38 Billion
# Expected last quarterly GOOG value: 55.31 Billion
# Predicted linear model value: 66.04 Billion | Error: -10.73 Billion
# Expected last quarterly FB value: 27.91 Billion
# Predicted linear model value: 28.25 Billion | Error: -0.34 Billion
# Expected last quarterly PG value: 20.35 Billion
# Predicted linear model value: 20.74 Billion | Error: -0.39 Billion
# Expected last quarterly GE value: 7.863 Billion
# Predicted linear model value: 6.98 Billion | Error: 0.88 Billion

# %% [markdown]
# ### Earning1

# %%
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM=np.array([3.48, 3.73, 2.91, 3.60,3.31, 2.59, 3.36, 3.34,3.60, 2.29, 2.56, 3.39,2.77, 2.80]) #, 2.77, 1.77]
y_MSFT=np.array([2.69, 2.50, 2.32, 2.69,2.69, 2.45, 2.48, 2.17,2.23, 1.95, 2.48, 2.17,2.03, 1.95])
y_AAPL=np.array([1.30, 1.43, 1.24, 1.40,1.41, 1.20, 1.18, 1.17,1.25, 1.40, 1.18, 1.24,1.18, 1.40])
y_GOOG=np.array([1.59, 1.25, 1.38, 1.06,1.56, 1.11, 1.44, 1.17,1.25, 1.20, 1.55, 1.51,1.76, 1.27])
y_FB=np.array([2.99, 2.92, 2.80, 2.68,2.72, 2.60, 2.53, 1.88,2.28, 1.76, 2.02, 1.95,2.01, 1.78])
y_PG=np.array([1.43, 1.38, 1.37, 1.33,1.32, 1.28, 1.24, 1.22,1.23, 1.22, 1.14, 1.10,1.03, 1.06])
y_GE=np.array([0.38, 0.31, 0.32, 0.24,0.28, 0.23, 0.21, 0.18,0.15, 0.12, 0.09, 0.07,0.05, 0.06])

x_log_IBM = np.log(x)

a_IBM, b_IBM = np.polyfit(x_log_IBM, y_IBM, 1)
a_MSFT, b_MSFT = np.polyfit(x_log_IBM, y_MSFT, 1)
a_AAPL, b_AAPL = np.polyfit(x_log_IBM, y_AAPL, 1)
a_GOOG, b_GOOG = np.polyfit(x_log_IBM, y_GOOG, 1)
a_FB, b_FB = np.polyfit(x_log_IBM, y_FB, 1)
a_PG, b_PG = np.polyfit(x_log_IBM, y_PG, 1)
a_GE, b_GE = np.polyfit(x_log_IBM, y_GE, 1)

y_log_IBM = a_IBM*x_log_IBM + b_IBM
y_log_MSFT = a_MSFT*x_log_IBM + b_MSFT
y_log_AAPL = a_AAPL*x_log_IBM + b_AAPL
y_log_GOOG = a_GOOG*x_log_IBM + b_GOOG
y_log_FB = a_FB*x_log_IBM + b_FB
y_log_PG = a_PG*x_log_IBM + b_PG
y_log_GE = a_GE*x_log_IBM + b_GE

plt.subplot(4,2,1)
plt.title('IBM')
plt.plot(x_log_IBM, y_IBM)
plt.plot(x_log_IBM,y_log_IBM)
plt.grid()

plt.subplot(4,2,2)
plt.title('Microsoft')
plt.plot(x_log_IBM, y_MSFT)
plt.plot(x_log_IBM,y_log_MSFT)
plt.grid()

plt.subplot(4,2,3)
plt.title('Apple')
plt.plot(x_log_IBM, y_AAPL)
plt.plot(x_log_IBM,y_log_AAPL)
plt.grid()

plt.subplot(4,2,4)
plt.title('Google')
plt.plot(x_log_IBM, y_GOOG)
plt.plot(x_log_IBM,y_log_GOOG)
plt.grid()

plt.subplot(4,2,5)
plt.title('Facebook')
plt.plot(x_log_IBM, y_FB)
plt.plot(x_log_IBM,y_log_FB)
plt.grid()

plt.subplot(4,2,6)
plt.title('PG')
plt.plot(x_log_IBM, y_PG)
plt.plot(x_log_IBM,y_log_PG)
plt.grid()

plt.subplot(4,2,7)
plt.title('General Electric')
plt.plot(x_log_IBM, y_GE)
plt.plot(x_log_IBM,y_log_GE)
plt.grid()

plt.tight_layout()

# %%
print(x_log_IBM[13])

print("Expected last quarterly IBM value: 2.8 Billion")
y_log_IBM = a_IBM*x_log_IBM[13] + b_IBM
print(f"Predicted linear model value: {y_log_IBM:.2f} Billion | Error: {(2.8 - y_log_IBM):.2f} Billion")

print("Expected last quarterly MSFT value: 1.95 Billion")
y_log_MSFT = a_MSFT*x_log_IBM[13] + b_MSFT
print(f"Predicted linear model value: {y_log_MSFT:.2f} Billion | Error: {(1.95 - y_log_MSFT):.2f} Billion")

print("Expected last quarterly AAPL value: 1.4 Billion")
y_log_AAPL = a_AAPL*x_log_IBM[13] + b_AAPL
print(f"Predicted linear model value: {y_log_AAPL:.2f} Billion | Error: {(1.4 - y_log_AAPL):.2f} Billion")

print("Expected last quarterly GOOG value: 1.27 Billion")
y_log_GOOG = a_GOOG*x_log_IBM[13] + b_GOOG
print(f"Predicted linear model value: {y_log_GOOG:.2f} Billion | Error: {(1.27 - y_log_GOOG):.2f} Billion")

print("Expected last quarterly FB value: 1.78 Billion")
y_log_FB = a_FB*x_log_IBM[13] + b_FB
print(f"Predicted linear model value: {y_log_FB:.2f} Billion | Error: {(1.78 - y_log_FB):.2f} Billion")

print("Expected last quarterly PG value: 1.06 Billion")
y_log_PG = a_PG*x_log_IBM[13] + b_PG
print(f"Predicted linear model value: {y_log_PG:.2f} Billion | Error: {(1.06 - y_log_PG):.2f} Billion")

print("Expected last quarterly GE value: 0.06 Billion")
y_log_GE = a_GE*x_log_IBM[13] + b_GE
print(f"Predicted linear model value: {y_log_GE:.2f} Billion | Error: {(0.06 - y_log_GE):.2f} Billion")
# Out:
# 3.970291913552122
# Expected last quarterly IBM value: 2.8 Billion
# Predicted linear model value: 2.93 Billion | Error: -0.13 Billion
# Expected last quarterly MSFT value: 1.95 Billion
# Predicted linear model value: 2.18 Billion | Error: -0.23 Billion
# Expected last quarterly AAPL value: 1.4 Billion
# Predicted linear model value: 1.26 Billion | Error: 0.14 Billion
# Expected last quarterly GOOG value: 1.27 Billion
# Predicted linear model value: 1.35 Billion | Error: -0.08 Billion
# Expected last quarterly FB value: 1.78 Billion
# Predicted linear model value: 2.01 Billion | Error: -0.23 Billion
# Expected last quarterly PG value: 1.06 Billion
# Predicted linear model value: 1.14 Billion | Error: -0.08 Billion
# Expected last quarterly GE value: 0.06 Billion
# Predicted linear model value: 0.10 Billion | Error: -0.04 Billion

# %% [markdown]
# ### Dividend1

# %%
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM=np.array([1.67,1.67, 1.67, 1.66,1.66, 1.66, 1.66, 1.65, 1.65, 1.65, 1.65, 1.64, 1.64, 1.64])#, 1.64])#, 1.63]
y_MSFT=np.array([0.83, 0.83, 0.75, 0.75,0.75, 0.75, 0.68, 0.68,0.62, 0.62, 0.56, 0.56,0.51, 0.51])#, 0.51])#, 0.51]
y_AAPL=np.array([0.25, 0.25, 0.24, 0.24,0.24, 0.24, 0.23, 0.23,0.23, 0.23, 0.23, 0.23,0.22, 0.22])#, 0.22])
y_PG=np.array([0.94, 0.94, 0.91, 0.91,0.91, 0.91, 0.87, 0.87,0.87, 0.87, 0.79, 0.79,0.79, 0.79])#, 0.75])
y_GE=np.array([0.08, 0.08, 0.08, 0.08,0.08, 0.08, 0.08, 0.08,0.01, 0.01, 0.01, 0.01,0.01, 0.01])#, 0.01])

a_IBM, b_IBM = np.polyfit(x, y_IBM, 1)
a_MSFT, b_MSFT = np.polyfit(x, y_MSFT, 1)
a_AAPL, b_AAPL = np.polyfit(x, y_AAPL, 1)
a_PG, b_PG = np.polyfit(x, y_PG, 1)
a_GE, b_GE = np.polyfit(x, y_GE, 1)

#add points to plot
plt.subplot(3,2,1)
plt.title('IBM')
plt.scatter(x, y_IBM, color="purple")
plt.plot(x, a_IBM*x+b_IBM, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,2)
plt.title('Micorsoft')
plt.scatter(x, y_MSFT, color="purple")
plt.plot(x, a_MSFT*x+b_MSFT, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,3)
plt.title('Apple')
plt.scatter(x, y_AAPL, color="purple")
plt.plot(x, a_AAPL*x+b_AAPL, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,4)
plt.title('PG')
plt.scatter(x, y_PG, color="purple")
plt.plot(x, a_PG*x+b_PG, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,5)
plt.title('General Electric')
plt.scatter(x, y_GE, color="purple")
plt.plot(x, a_GE*x+b_GE, color='red', linestyle='--', linewidth=2)
plt.grid()

plt.tight_layout()

# %%
print(x_log_IBM[13])

print("Expected last quarterly IBM value: 1.64")
y_log_IBM = a_IBM*x_log_IBM[13] + b_IBM
print(f"Predicted linear model value: {y_log_IBM:.2f} | Error: {(1.64 - y_log_IBM):.2f}")

print("Expected last quarterly MSFT value: 0.51")
y_log_MSFT = a_MSFT*x_log_IBM[13] + b_MSFT
print(f"Predicted linear model value: {y_log_MSFT:.2f} | Error: {(0.51 - y_log_MSFT):.2f}")

print("Expected last quarterly AAPL value: 0.22")
y_log_AAPL = a_AAPL*x_log_IBM[13] + b_AAPL
print(f"Predicted linear model value: {y_log_AAPL:.2f} | Error: {(0.22 - y_log_AAPL):.2f}")

print("Expected last quarterly PG value: 0.79")
y_log_PG = a_PG*x_log_IBM[13] + b_PG
print(f"Predicted linear model value: {y_log_PG:.2f} | Error: {(0.79 - y_log_PG):.2f}")

print("Expected last quarterly GE value: 0.01")
y_log_GE = a_GE*x_log_IBM[13] + b_GE
print(f"Predicted linear model value: {y_log_GE:.2f} | Error: {(0.01 - y_log_GE):.2f}")
# Out:
# 3.970291913552122
# Expected last quarterly IBM value: 1.64
# Predicted linear model value: 1.67 | Error: -0.03
# Expected last quarterly MSFT value: 0.51
# Predicted linear model value: 0.82 | Error: -0.31
# Expected last quarterly AAPL value: 0.22
# Predicted linear model value: 0.25 | Error: -0.03
# Expected last quarterly PG value: 0.79
# Predicted linear model value: 0.94 | Error: -0.15
# Expected last quarterly GE value: 0.01
# Predicted linear model value: 0.09 | Error: -0.08

# %% [markdown]
# ## Exponential_Model

# %% [markdown]
# ### Revenue2

# %%
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM=np.array([16.69,13.25,14.22,13.19,16.69,14.11,15.54,14.2,17.38,14.75,15.48,14.25,15.77,14.46])
y_MSFT=np.array([64.73, 61.86, 56.19, 52.86, 52.75, 50.12, 51.86, 49.36, 51.73, 45.32, 51.86, 45.32, 46.15, 41.7])
y_AAPL=np.array([85.78, 90.75, 89.50, 81.80, 82.96, 94.84, 90.15, 82.96, 97.28, 123.94, 83.36, 81.43, 89.58, 111.43])
y_GOOG=np.array([84.74, 80.54, 86.31, 76.69, 74.60, 69.79, 76.05, 69.09, 69.68, 68.01, 75.32, 65.12, 61.88, 55.31])
y_FB=np.array([39.07, 38.79, 32.17, 27.71, 29.08, 28.65, 33.67, 29.01, 28.82, 27.91, 33.67, 29.01, 28.82, 27.91])
y_PG=np.array([18.00, 18.10, 19.60, 20.10, 19.20, 19.60, 20.70, 21.10, 20.00, 20.50, 20.70, 20.90, 20.53, 20.35]) #, 20.20, 20.50]
y_GE=np.array([9.093, 8.938, 8.367, 7.954, 8.813, 8.675, 8.367, 5.810, 6.576, 6.675, 6.900, 5.469, 7.904, 7.863])

coefficient_IBM = np.polyfit(x, np.log(y_IBM), 1)
coefficient_MSFT = np.polyfit(x, np.log(y_MSFT), 1)
coefficient_AAPL = np.polyfit(x, np.log(y_AAPL), 1)
coefficient_GOOG = np.polyfit(x, np.log(y_GOOG), 1)
coefficient_FB = np.polyfit(x, np.log(y_FB), 1)
coefficient_PG = np.polyfit(x, np.log(y_PG), 1)
coefficient_GE = np.polyfit(x, np.log(y_GE), 1)

a_IBM = np.exp(coefficient_IBM[1])
b_IBM = coefficient_IBM[0]
a_MSFT = np.exp(coefficient_MSFT[1])
b_MSFT = coefficient_MSFT[0]
a_AAPL = np.exp(coefficient_AAPL[1])
b_AAPL = coefficient_AAPL[0]
a_GOOG = np.exp(coefficient_GOOG[1])
b_GOOG = coefficient_GOOG[0]
a_FB = np.exp(coefficient_FB[1])
b_FB = coefficient_FB[0]
a_PG = np.exp(coefficient_PG[1])
b_PG = coefficient_PG[0]
a_GE = np.exp(coefficient_GE[1])
b_GE = coefficient_GE[0]

plt.subplot(4,2,1)
plt.title('IBM')
plt.scatter(x, y_IBM, color="purple")
plt.plot(x, a_IBM * np.exp(b_IBM * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,2)
plt.title('MSFT')
plt.scatter(x, y_MSFT, color="purple")
plt.plot(x,a_MSFT * np.exp(b_MSFT * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,3)
plt.title('AAPL')
plt.scatter(x, y_AAPL, color="purple")
plt.plot(x,a_AAPL * np.exp(b_AAPL * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,4)
plt.title('GOOG')
plt.scatter(x, y_GOOG, color="purple")
plt.plot(x,a_GOOG * np.exp(b_GOOG * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,5)
plt.title('FB')
plt.scatter(x, y_FB, color="purple")
plt.plot(x,a_FB * np.exp(b_FB * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,6)
plt.title('PG')
plt.scatter(x, y_PG, color="purple")
plt.plot(x,a_PG * np.exp(b_PG * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,7)
plt.title('GE')
plt.scatter(x, y_GE, color="purple")
plt.plot(x,a_GE * np.exp(b_GE * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.tight_layout()

# %%
print(x[13])

print("Expected last quarterly IBM value: 14.46 Billion")
y_IBM = a_IBM * np.exp(b_IBM * x[13])
print(f"Predicted exponential model value: {y_IBM:.2f} Billion | Error: {(14.46 - y_IBM):.2f} Billion")

print("Expected last quarterly MSFT value: 41.7 Billion")
y_MSFT = a_MSFT * np.exp(b_MSFT * x[13])
print(f"Predicted exponential model value: {y_MSFT:.2f} Billion | Error: {(41.7 - y_MSFT):.2f} Billion")

print("Expected last quarterly AAPL value: 111.43 Billion")
y_AAPL = a_AAPL * np.exp(b_AAPL * x[13])
print(f"Predicted exponential model value: {y_AAPL:.2f} Billion | Error: {(111.43 - y_AAPL):.2f} Billion")

print("Expected last quarterly GOOG value: 55.31 Billion")
y_GOOG = a_GOOG * np.exp(b_GOOG * x[13])
print(f"Predicted exponential model value: {y_GOOG:.2f} Billion | Error: {(55.31 - y_GOOG):.2f} Billion")

print("Expected last quarterly FB value: 27.91 Billion")
y_FB = a_FB * np.exp(b_FB * x[13])
print(f"Predicted exponential model value: {y_FB:.2f} Billion | Error: {(27.91 - y_FB):.2f} Billion")

print("Expected last quarterly PG value: 20.35 Billion")
y_PG = a_PG * np.exp(b_PG * x[13])
print(f"Predicted exponential model value: {y_PG:.2f} Billion | Error: {(20.35 - y_PG):.2f} Billion")

print("Expected last quarterly GE value: 7.863 Billion")
y_GE = a_GE * np.exp(b_GE * x[13])
print(f"Predicted exponential model value: {y_GE:.2f} Billion | Error: {(7.863 - y_GE):.2f} Billion")
# Out:
# 53
# Expected last quarterly IBM value: 14.46 Billion
# Predicted exponential model value: 15.19 Billion | Error: -0.73 Billion
# Expected last quarterly MSFT value: 41.7 Billion
# Predicted exponential model value: 43.32 Billion | Error: -1.62 Billion
# Expected last quarterly AAPL value: 111.43 Billion
# Predicted exponential model value: 97.28 Billion | Error: 14.15 Billion
# Expected last quarterly GOOG value: 55.31 Billion
# Predicted exponential model value: 60.84 Billion | Error: -5.53 Billion
# Expected last quarterly FB value: 27.91 Billion
# Predicted exponential model value: 27.66 Billion | Error: 0.25 Billion
# Expected last quarterly PG value: 20.35 Billion
# Predicted exponential model value: 21.16 Billion | Error: -0.81 Billion
# Expected last quarterly GE value: 7.863 Billion
# Predicted exponential model value: 6.51 Billion | Error: 1.35 Billion

# %% [markdown]
# ### Earning2

# %%
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM=np.array([3.48, 3.73, 2.91, 3.60,3.31, 2.59, 3.36, 3.34,3.60, 2.29, 2.56, 3.39,2.77, 2.80])#, 2.77, 1.77]
y_MSFT=np.array([2.69, 2.50, 2.32, 2.69,2.69, 2.45, 2.48, 2.17,2.23, 1.95, 2.48, 2.17,2.03, 1.95])
y_AAPL=np.array([1.30, 1.43, 1.24, 1.40,1.41, 1.20, 1.18, 1.17,1.25, 1.40, 1.18, 1.24,1.18, 1.40])
y_GOOG=np.array([1.59, 1.25, 1.38, 1.06,1.56, 1.11, 1.44, 1.17,1.25, 1.20, 1.55, 1.51,1.76, 1.27])
y_FB=np.array([2.99, 2.92, 2.80, 2.68,2.72, 2.60, 2.53, 1.88,2.28, 1.76, 2.02, 1.95,2.01, 1.78])
y_PG=np.array([1.43, 1.38, 1.37, 1.33,1.32, 1.28, 1.24, 1.22,1.23, 1.22, 1.14, 1.10,1.03, 1.06])
y_GE=np.array([0.38, 0.31, 0.32, 0.24,0.28, 0.23, 0.21, 0.18,0.15, 0.12, 0.09, 0.07,0.05, 0.06])

coefficient_IBM = np.polyfit(x, np.log(y_IBM), 1)
coefficient_MSFT = np.polyfit(x, np.log(y_MSFT), 1)
coefficient_AAPL = np.polyfit(x, np.log(y_AAPL), 1)
coefficient_GOOG = np.polyfit(x, np.log(y_GOOG), 1)
coefficient_FB = np.polyfit(x, np.log(y_FB), 1)
coefficient_PG = np.polyfit(x, np.log(y_PG), 1)
coefficient_GE = np.polyfit(x, np.log(y_GE), 1)

a_IBM = np.exp(coefficient_IBM[1])
b_IBM = coefficient_IBM[0]
a_MSFT = np.exp(coefficient_MSFT[1])
b_MSFT = coefficient_MSFT[0]
a_AAPL = np.exp(coefficient_AAPL[1])
b_AAPL = coefficient_AAPL[0]
a_GOOG = np.exp(coefficient_GOOG[1])
b_GOOG = coefficient_GOOG[0]
a_FB = np.exp(coefficient_FB[1])
b_FB = coefficient_FB[0]
a_PG = np.exp(coefficient_PG[1])
b_PG = coefficient_PG[0]
a_GE = np.exp(coefficient_GE[1])
b_GE = coefficient_GE[0]

plt.subplot(4,2,1)
plt.title('IBM')
plt.scatter(x, y_IBM, color="purple")
plt.plot(x, a_IBM * np.exp(b_IBM * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,2)
plt.title('MSFT')
plt.scatter(x, y_MSFT, color="purple")
plt.plot(x,a_MSFT * np.exp(b_MSFT * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,3)
plt.title('AAPL')
plt.scatter(x, y_AAPL, color="purple")
plt.plot(x,a_AAPL * np.exp(b_AAPL * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,4)
plt.title('GOOG')
plt.scatter(x, y_GOOG, color="purple")
plt.plot(x,a_GOOG * np.exp(b_GOOG * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,5)
plt.title('FB')
plt.scatter(x, y_FB, color="purple")
plt.plot(x,a_FB * np.exp(b_FB * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,6)
plt.title('PG')
plt.scatter(x, y_PG, color="purple")
plt.plot(x,a_PG * np.exp(b_PG * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(4,2,7)
plt.title('GE')
plt.scatter(x, y_GE, color="purple")
plt.plot(x,a_GE * np.exp(b_GE * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.tight_layout()

# %%
print(x[13])

print("Expected last quarterly IBM value: 2.8 Billion")
y_IBM = a_IBM * np.exp(b_IBM * x[13])
print(f"Predicted linear model value: {y_IBM:.2f} Billion | Error: {(2.8 - y_IBM):.2f} Billion")

print("Expected last quarterly MSFT value: 1.95 Billion")
y_MSFT = a_MSFT * np.exp(b_MSFT * x[13])
print(f"Predicted linear model value: {y_MSFT:.2f} Billion | Error: {(1.95 - y_MSFT):.2f} Billion")

print("Expected last quarterly AAPL value: 1.4 Billion")
y_AAPL = a_AAPL * np.exp(b_AAPL * x[13])
print(f"Predicted linear model value: {y_AAPL:.2f} Billion | Error: {(1.4 - y_AAPL):.2f} Billion")

print("Expected last quarterly GOOG value: 1.27 Billion")
y_GOOG = a_GOOG * np.exp(b_GOOG * x[13])
print(f"Predicted linear model value: {y_GOOG:.2f} Billion | Error: {(1.27 - y_GOOG):.2f} Billion")

print("Expected last quarterly FB value: 1.78 Billion")
y_FB = a_FB * np.exp(b_FB * x[13])
print(f"Predicted linear model value: {y_FB:.2f} Billion | Error: {(1.78 - y_FB):.2f} Billion")

print("Expected last quarterly PG value: 1.06 Billion")
y_PG = a_PG * np.exp(b_PG * x[13])
print(f"Predicted linear model value: {y_PG:.2f} Billion | Error: {(1.06 - y_PG):.2f} Billion")

print("Expected last quarterly GE value: 0.06 Billion")
y_GE = a_GE * np.exp(b_GE * x[13])
print(f"Predicted linear model value: {y_GE:.2f} Billion | Error: {(0.06 - y_GE):.2f} Billion")
# Out:
# 53
# Expected last quarterly IBM value: 2.8 Billion
# Predicted linear model value: 2.76 Billion | Error: 0.04 Billion
# Expected last quarterly MSFT value: 1.95 Billion
# Predicted linear model value: 2.03 Billion | Error: -0.08 Billion
# Expected last quarterly AAPL value: 1.4 Billion
# Predicted linear model value: 1.24 Billion | Error: 0.16 Billion
# Expected last quarterly GOOG value: 1.27 Billion
# Predicted linear model value: 1.41 Billion | Error: -0.14 Billion
# Expected last quarterly FB value: 1.78 Billion
# Predicted linear model value: 1.76 Billion | Error: 0.02 Billion
# Expected last quarterly PG value: 1.06 Billion
# Predicted linear model value: 1.06 Billion | Error: 0.00 Billion
# Expected last quarterly GE value: 0.06 Billion
# Predicted linear model value: 0.06 Billion | Error: 0.00 Billion

# %% [markdown]
# ### Dividend2

# %%
x=np.array([1,5,9,13,17,21,25,29,33,37,41,45, 49, 53])

y_IBM=np.array([1.67,1.67, 1.67, 1.66,1.66, 1.66, 1.66, 1.65, 1.65, 1.65, 1.65, 1.64, 1.64, 1.64]) #, 1.64, 1.63]
y_MSFT=np.array([0.83, 0.83, 0.75, 0.75,0.75, 0.75, 0.68, 0.68,0.62, 0.62, 0.56, 0.56,0.51, 0.51])#, 0.51, 0.51]
y_AAPL=np.array([0.25, 0.25, 0.24, 0.24,0.24, 0.24, 0.23, 0.23,0.23, 0.23, 0.23, 0.23,0.22, 0.22])#, 0.22]
y_PG=np.array([0.94, 0.94, 0.91, 0.91,0.91, 0.91, 0.87, 0.87,0.87, 0.87, 0.79, 0.79,0.79, 0.79])#, 0.75]
y_GE=np.array([0.08, 0.08, 0.08, 0.08,0.08, 0.08, 0.08, 0.08,0.01, 0.01, 0.01, 0.01,0.01, 0.01])#, 0.01]

coefficient_IBM = np.polyfit(x, np.log(y_IBM), 1)
coefficient_MSFT = np.polyfit(x, np.log(y_MSFT), 1)
coefficient_AAPL = np.polyfit(x, np.log(y_AAPL), 1)
coefficient_PG = np.polyfit(x, np.log(y_PG), 1)
coefficient_GE = np.polyfit(x, np.log(y_GE), 1)

a_IBM = np.exp(coefficient_IBM[1])
b_IBM = coefficient_IBM[0]
a_MSFT = np.exp(coefficient_MSFT[1])
b_MSFT = coefficient_MSFT[0]
a_AAPL = np.exp(coefficient_AAPL[1])
b_AAPL = coefficient_AAPL[0]
a_PG = np.exp(coefficient_PG[1])
b_PG = coefficient_PG[0]
a_GE = np.exp(coefficient_GE[1])
b_GE = coefficient_GE[0]

plt.subplot(3,2,1)
plt.title('IBM')
plt.scatter(x, y_IBM, color="purple")
plt.plot(x, a_IBM * np.exp(b_IBM * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,2)
plt.title('MSFT')
plt.scatter(x, y_MSFT, color="purple")
plt.plot(x,a_MSFT * np.exp(b_MSFT * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,3)
plt.title('AAPL')
plt.scatter(x, y_AAPL, color="purple")
plt.plot(x,a_AAPL * np.exp(b_AAPL * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,4)
plt.title('PG')
plt.scatter(x, y_PG, color="purple")
plt.plot(x,a_PG * np.exp(b_PG * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.subplot(3,2,5)
plt.title('GE')
plt.scatter(x, y_GE, color="purple")
plt.plot(x,a_GE * np.exp(b_GE * x), color='red', linestyle='--', linewidth=2)
plt.grid()

plt.tight_layout()

# %%
print(x[13])

print("Expected last quarterly IBM value: 1.64")
y_IBM = a_IBM * np.exp(b_IBM * x[13])
print(f"Predicted linear model value: {y_IBM:.2f} | Error: {(1.64 - y_IBM):.2f}")

print("Expected last quarterly MSFT value: 0.51")
y_MSFT = a_MSFT * np.exp(b_MSFT * x[13])
print(f"Predicted linear model value: {y_MSFT:.2f} | Error: {(0.51 - y_MSFT):.2f}")

print("Expected last quarterly AAPL value: 0.22")
y_AAPL = a_AAPL * np.exp(b_AAPL * x[13])
print(f"Predicted linear model value: {y_AAPL:.2f} | Error: {(0.22 - y_AAPL):.2f}")

print("Expected last quarterly PG value: 0.79")
y_PG = a_PG * np.exp(b_PG * x[13])
print(f"Predicted linear model value: {y_PG:.2f} | Error: {(0.79 - y_PG):.2f}")

print("Expected last quarterly GE value: 0.01")
y_GE = a_GE * np.exp(b_GE * x[13])
print(f"Predicted linear model value: {y_GE:.2f} | Error: {(0.01 - y_GE):.2f}")
# Out:
# 53
# Expected last quarterly IBM value: 1.64
# Predicted linear model value: 1.64 | Error: 0.00
# Expected last quarterly MSFT value: 0.51
# Predicted linear model value: 0.51 | Error: -0.00
# Expected last quarterly AAPL value: 0.22
# Predicted linear model value: 0.22 | Error: -0.00
# Expected last quarterly PG value: 0.79
# Predicted linear model value: 0.79 | Error: 0.00
# Expected last quarterly GE value: 0.01
# Predicted linear model value: 0.01 | Error: 0.00

# %% [markdown]
# ## PowerCurve_Model

# %% [markdown]
# ### Revenue3

# %% [markdown]
# ### Earning3

# %% [markdown]
# ### Dividend3
